# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_excel('data3.xlsx')

# %%
dataset.head(10)
# Out:
#    Years Of Experience  Salary
# 0                  1.0   20000
# 1                  2.0   34567
# 2                  3.0   56789
# 3                  4.0   23456
# 4                  2.0   34678
# 5                  3.0   67543
# 6                  4.0   46532
# 7                  3.0   23456
# 8                  2.0   78956
# 9                  2.0   12456

# %%
X= dataset.iloc[:,:-1].values

# %%
Y= dataset.iloc[:,-1].values

# %%
X
# Out:
# array([[1. ],
#        [2. ],
#        [3. ],
#        [4. ],
#        [2. ],
#        [3. ],
#        [4. ],
#        [3. ],
#        [2. ],
#        [2. ],
#        [3. ],
#        [3. ],
#        [4. ],
#        [4. ],
#        [5.5],
#        [4.5],
#        [3.5],
#        [2.5],
#        [2. ],
#        [3. ],
#        [1. ],
#        [1. ],
#        [2. ],
#        [2. ],
#        [3. ],
#        [3. ],
#        [4. ],
#        [5. ],
#        [6. ],
#        [2. ]])

# %%
Y
# Out:
# array([20000, 34567, 56789, 23456, 34678, 67543, 46532, 23456, 78956,
#        12456, 78654, 90876, 74695, 78541, 23698, 58963, 45362, 17485,
#        98756, 58964, 36547, 45287, 75984, 69857, 12547, 36528, 85421,
#        96857, 36524, 14523])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg= LinearRegression()

# %%
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
# array([[3. ],
#        [6. ],
#        [4. ],
#        [3. ],
#        [4. ],
#        [3. ],
#        [5. ],
#        [3. ],
#        [2.5],
#        [2. ]])

# %% [raw]
# Y_pred = reg.predict(X_test)

# %%
Y_pred = reg.predict(X_test)

# %%
Y_pred
# Out:
# array([45395.6336041 , 47080.3638307 , 45957.2103463 , 45395.6336041 ,
#        45957.2103463 , 45395.6336041 , 46518.7870885 , 45395.6336041 ,
#        45114.84523301, 44834.05686191])

# %%
Y_test
# Out:
# array([56789, 36524, 78541, 78654, 85421, 12547, 96857, 90876, 17485,
#        75984])

# %% [raw]
# %pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X_train, Y_train, color = 'purple')
plt.plot(X_train, reg.predict(X_train), color = 'green')

# %%
plt.scatter(X_test, Y_test, color = 'purple')
plt.plot(X_test, reg.predict(X_test), color = 'green')
